# %%
from significance_of_mean_cuda import significance_of_mean_cuda
from utils import significance_of_mean, getdf, my_scatter_plot
import numpy as np
import time
import multiprocessing
import concurrent.futures as cf
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import truncnorm
import matplotlib.pyplot as plt
from IPython.display import Image
import sklearn
import time
from scipy.stats import ttest_ind, ttest_rel, chisquare, ks_2samp
import pandas as pd
import seaborn as sns

import matplotlib as mpl

mpl.rcParams['text.usetex'] = False  # not really needed

from scipy import stats
from scipy.stats import mannwhitneyu

# %%
def p_value_calc(args):
    a,b, bins = args
    p=significance_of_mean(a,b, bins)[0]
    return p

# %% [markdown]
# ### Load data from MC approximation of permutation test

# %%
def loadMcResult(sampleShape, mean, path="dataFastPerm/uniform/data"):
    X_list = list()
    y_list = list()
    p_val_list = list()
    time_listMc = list()
    for S in sampleShape:
        X = pd.read_csv(path + "_{}/X_{}.csv".format(mean, S))
        Y = pd.read_csv(path + "_{}/y_{}.csv".format(mean, S))
        p_val = pd.read_csv(path + "_{}/error_{}.csv".format(mean, S))
        timeMc = pd.read_csv(path + "_{}/Time_{}.csv".format(mean, S))
    
    
        X.columns = range(X.shape[1])
        Y.columns = range(Y.shape[1])
        p_val.columns = range(p_val.shape[1])
        timeMc.columns = range(timeMc.shape[1])
    
    
        X_list.append([np.array(x.split(" ")[1:]).astype(float) for x in X[0].values])
        y_list.append([np.array(y.split(" ")[1:]).astype(float) for y in Y[0].values])
        p_val_list.append(np.array([float(p[0].split(" ")[1]) for p in p_val.values]))
        time_listMc.append([float(t[0].split(" ")[1]) for t in timeMc.values])
    
    return X_list, y_list, p_val_list, time_listMc

# %% [markdown]
# ### Get p-value for the the parallelized permutation test

# %%
def run_test(X,Y,bins, parallel=True, midP=False):

    
    
    if parallel:
        #Exact test
        SGM = significance_of_mean_cuda(bins, dtype_v=np.uint32,dtype_A=np.float64)
        SGM.run(X.reshape(1,-1),Y.reshape(1,-1), midP)
        p_val = SGM.p_values[0]
    else:
        p_val = p_value_calc([list(X), list(Y), bins])

    return p_val

# %% [markdown]
# ### Get all p-values from the prallelized exact test from the same data as the MC version

# %%
def shiftMethod(X_list, y_list, bins, parallel=True, midP=False):
    pe_list = list()
    TIME = list()

    for Xp, yp in zip(X_list, y_list):
        Xp = np.asarray(Xp).T
        yp = np.asarray(yp).T
        
        p_e = list()
        time_list = list()
    
        for x, y in zip(Xp, yp):
            
            start = time.time()
            p_e.append(run_test(y, x, bins, parallel, midP))
            end = time.time()
        
            time_list.append(end - start)
    
        pe_list.append(p_e)
        TIME.append(time_list)
    
    return pe_list, TIME

# %%
def ttest(X_list, y_list):
    pt_list = list()

    for Xp, yp in zip(X_list, y_list):
        Xp = np.asarray(Xp).T
        yp = np.asarray(yp).T
        
        p_t = list()
    
        for x, y in zip(Xp, yp):
            
            t, p = ttest_ind(y, x)
            p = p/2
            if t<0:
                p = 1-p
       
            p_t.append(p)
            
        pt_list.append(p_t)

    
    return pt_list

# %%
def mannWhitney(X_list, y_list, alternative="less"):
    assert alternative in ["less","greater","two-tail"]
    pmw_list = list()

    for Xp, yp in zip(X_list, y_list):
        Xp = np.asarray(Xp).T
        yp = np.asarray(yp).T
        
        p_mw = list()
    
        for x, y in zip(Xp, yp):
            

            p = mannwhitneyu(x, y, alternative=alternative)[1]
            
            
            p_mw.append(p)
            
        pmw_list.append(p_mw)

    
    return pmw_list

# %% [markdown]
# ### Compare parallelized and MC version

# %% [markdown]
# ### Calibration-plot

# %%
from scipy import stats
def r2(x, y):
    #return stats.pearsonr(x, y)[0] ** 2
    #return mean_squared_error(x,y)
    z=(x-y)/y
    z_abs = np.abs(z)
    return np.mean(z_abs)

def my_scatter_plot(df,save_name):
    sns.set(style="white")
    sns.set_context("talk")
    low = min(df["Theoretical p-value"])
    hi = max(df["Theoretical p-value"])
    f, ax = plt.subplots(figsize=(7, 7))
    ax.set(xscale="log", yscale="log")
    
    err2 = r2(df["Observed p-value"], df["Theoretical p-value"])
    
    g=sns.regplot(x='Theoretical p-value', y ='Observed p-value', data=df,  ax=ax, fit_reg=False, 
                  scatter_kws={"s": 5})
    g.plot([low,hi], [low,hi], 'k-', linewidth=.5)
    
    sns.despine()
    plt.title("Mean relative error : {}".format(np.around(err2,6)))
    f.tight_layout()
    f.savefig(save_name)

# %%
def muliplot(df1, df2, df3,save_name):
    sns.set(style="white")
    sns.set_context("talk")
    
    low = min(df1["Theoretical p-value"])
    hi = max(df1["Theoretical p-value"])
    f, ax = plt.subplots(figsize=(7, 7))
    ax.set(xscale="log", yscale="log")
    
    
    
    g1=sns.regplot(x='Theoretical p-value', y ='Observed p-value', data=df1,  ax=ax, fit_reg=False, 
                  scatter_kws={"s": 5})
    
    g2=sns.regplot(x='Theoretical p-value', y ='Observed p-value', data=df2,  ax=ax, fit_reg=False, 
                  scatter_kws={"s": 5})
    
    g3=sns.regplot(x='Theoretical p-value', y ='Observed p-value', data=df3,  ax=ax, fit_reg=False, 
                  scatter_kws={"s": 5})
    
    g1.plot([low,hi], [low,hi], 'k-', linewidth=.5)
    g2.plot([low,hi], [low,hi], 'k-', linewidth=.5)
    g3.plot([low,hi], [low,hi], 'k-', linewidth=.5)
    
    sns.despine()
    f.tight_layout()
    f.savefig(save_name)

# %%
def getPATH(path, suffix, prefix):
    return path + '/'+ suffix + '/' + prefix

# %%
path = "figures/paralellVsFastApprox"

# %% [markdown]
# ## Sample sizes of X and Y

# %%
#sampleShape = [10,50,100,150,200,250,300]
sampleShape = [10,50,100,150,200,250,300]

# %% [markdown]
# # Calibration: with $X \sim N(5.0,1)$ and $Y\sim N(5.0,1)$

# %% [markdown]
# ## Load data

# %%
mean=5

# %%
X_list_, y_list_, p_val_list_, time_listMc_ = loadMcResult(sampleShape, mean)

# %%
pe_list_, TIME_ = shiftMethod(np.asarray(X_list_), np.asarray(y_list_), 40)

# %%
pmw_list5_2 = mannWhitney(np.asarray(X_list_), np.asarray(y_list_))

# %% [markdown]
# # $|n|=|m|=10$

# %% [markdown]
# ## Parallelized exact test

# %%
len(pe_list_[0])
# Out:
# 1000

# %%
pDfExact = getdf(pe_list_[0], 1000)
my_scatter_plot(pDfExact,"figures/calibration/norm_5_1_s10/e")

# %% [markdown]
# ## Fast approximation

# %%
pDfFast = getdf(p_val_list_[0], 1000)
my_scatter_plot(pDfFast,"figures/calibration/norm_5_1_s10/f")

# %% [markdown]
# ## Mann Whitney

# %%
pDfMW = getdf(pmw_list5_2[0], 1000)
my_scatter_plot(pDfMW,"figures/calibration/norm_5_1_s10/mw")

# %% [markdown]
# ## t-test

# %%
pt_list5_2 = ttest(np.asarray(X_list_), np.asarray(y_list_))

# %%
pDfTtest = getdf(pt_list5_2[0], 1000)
my_scatter_plot(pDfTtest,"figures/calibration/norm_5_1_s10/t")

# %% [markdown]
# # $|n|=|m|=50$

# %% [markdown]
# ## Parallelized exact test

# %%
pDf = getdf(pe_list_[1], 1000)
my_scatter_plot(pDf,"figures/calibration/norm_5_1_s50/e")

# %% [markdown]
# ## Fast approximation

# %%
pDf = getdf(p_val_list_[1], 1000)
my_scatter_plot(pDf,"figures/calibration/norm_5_1_s50/f")

# %% [markdown]
# ## Mann whitney

# %%
pDf = getdf(pmw_list5_2[1], 1000)
my_scatter_plot(pDf,"figures/calibration/norm_5_1_s50/mw")

# %% [markdown]
# ## t-test

# %%
pDf = getdf(pt_list5_2[1], 1000)
my_scatter_plot(pDf,"figures/calibration/norm_5_1_s50/t")

# %% [markdown]
# # $|n|=|m|=100$

# %% [markdown]
# ## Parallelized exact test

# %%
pDf = getdf(pe_list_[2], 1000)
my_scatter_plot(pDf,"figures/calibration/norm_5_1_s100/e")

# %% [markdown]
# ## Fast approximations

# %%
pDf = getdf(p_val_list_[2], 1000)
my_scatter_plot(pDf,"figures/calibration/norm_5_1_s100/f")

# %% [markdown]
# ## Mann Whitney

# %%
pDf = getdf(pmw_list5_2[2], 1000)
my_scatter_plot(pDf,"figures/calibration/norm_5_1_s100/mw")

# %% [markdown]
# ## t-test

# %%
pDf = getdf(pt_list5_2[2], 1000)
my_scatter_plot(pDf,"figures/calibration/norm_5_1_s100/t")

# %% [markdown]
# # $|n|=|m|=150$

# %% [markdown]
# ## Parallelized exact test

# %%
pDf = getdf(pe_list_[3], 1000)
my_scatter_plot(pDf,"figures/calibration/norm_5_1_s150/e")

# %% [markdown]
# ## Fast approximation

# %%
pDf = getdf(p_val_list_[3], 1000)
my_scatter_plot(pDf,"figures/calibration/norm_5_1_s150/f")

# %% [markdown]
# ## Mann Whitney

# %%
pDf = getdf(pmw_list5_2[3], 1000)
my_scatter_plot(pDf,"figures/calibration/norm_5_1_s150/mw")

# %% [markdown]
# ## t-test

# %%
pDf = getdf(pt_list5_2[3], 1000)
my_scatter_plot(pDf,"figures/calibration/norm_5_1_s150/t")

# %% [markdown]
# # $|n|=|m|=200$

# %% [markdown]
# ## Parallelized exact test

# %%
pDf = getdf(pe_list_[4], 1000)
my_scatter_plot(pDf,"figures/calibration/norm_5_1_s200/e")

# %% [markdown]
# ## Fast approximation

# %%
pDf = getdf(p_val_list_[4], 1000)
my_scatter_plot(pDf,"figures/calibration/norm_5_1_s200/f")

# %% [markdown]
# ## Mann Whitney

# %%
pDf = getdf(pmw_list5_2[4], 1000)
my_scatter_plot(pDf,"figures/calibration/norm_5_1_s200/mw")

# %% [markdown]
# ## t-test

# %%
pDf = getdf(pt_list5_2[4], 1000)
my_scatter_plot(pDf,"figures/calibration/norm_5_1_s200/t")

# %% [markdown]
# ## $|n|=|m|=250$

# %% [markdown]
# ## Parallelized exact test

# %%
pDf = getdf(pe_list_[5], 1000)
my_scatter_plot(pDf,"figures/calibration/norm_5_1_s250/e")

# %% [markdown]
# ## Fast approximation

# %%
pDf = getdf(p_val_list_[5], 1000)
my_scatter_plot(pDf,"figures/calibration/norm_5_1_s250/f")

# %% [markdown]
# ## Mann Whitney

# %%
pDf = getdf(pmw_list5_2[5], 1000)
my_scatter_plot(pDf,"figures/calibration/norm_5_1_s250/mw")

# %% [markdown]
# ## t-test

# %%
pDf = getdf(pt_list5_2[5], 1000)
my_scatter_plot(pDf,"figures/calibration/norm_5_1_s250/t")

# %% [markdown]
# ## $|n|=|m|=300$

# %% [markdown]
# ## Parallelized exact test

# %%
pDf = getdf(pe_list_[6], 1000)
my_scatter_plot(pDf,"figures/calibration/norm_5_1_s300/e")

# %% [markdown]
# ## Fast approximation

# %%
pDf = getdf(p_val_list_[6], 1000)
my_scatter_plot(pDf,"figures/calibration/norm_5_1_s300/f")

# %% [markdown]
# ## Mann Whitney

# %%
pDf = getdf(pmw_list5_2[6], 1000)
my_scatter_plot(pDf,"figures/calibration/norm_5_1_s300/mw")

# %% [markdown]
# ## t-test

# %%
pDf = getdf(pt_list5_2[6], 1000)
my_scatter_plot(pDf,"figures/calibration/norm_5_1_s300/t")

# %% [markdown]
# # Calibration: with $X \sim \beta (0.5,0.5)$ and $Y\sim \beta(0.5,0.5)$

# %%
mean=0.5
sampleShape = [10,50,100,150,200]

# %%
X_list_, y_list_, p_val_list_, time_listMc_ = loadMcResult(sampleShape, mean, path="dataFastPerm/uniform/beta_data")

# %%
pe_list_, TIME_ = shiftMethod(np.asarray(X_list_), np.asarray(y_list_), 40)

# %%
pmw_list5_2 = mannWhitney(np.asarray(X_list_), np.asarray(y_list_))

# %% [markdown]
# # $|n|=|m|=10$

# %% [markdown]
# # Parallelized exact

# %%
pDf = getdf(pe_list_[0], 1000)
my_scatter_plot(pDf,"figures/calibration/beta_05_05_s10/e")

# %% [markdown]
# # Fast approximation

# %%
pDf = getdf(p_val_list_[0], 1000)
my_scatter_plot(pDf,"figures/calibration/beta_05_05_s10/f")

# %% [markdown]
# # Mann Whitney

# %%
pDf = getdf(pmw_list5_2[0], 1000)
my_scatter_plot(pDf,"figures/calibration/beta_05_05_s10/mw")

# %% [markdown]
# # t-test

# %%
pDf = getdf(pt_list5_2[0], 1000)
my_scatter_plot(pDf,"figures/calibration/beta_05_05_s10/t")

# %% [markdown]
# # $|n|=|m|=50$

# %% [markdown]
# # Paralellized exact

# %%
pDf = getdf(pe_list_[1], 1000)
my_scatter_plot(pDf,"figures/calibration/beta_05_05_s50/e")

# %% [markdown]
# # Fast approximation

# %%
pDf = getdf(p_val_list_[1], 1000)
my_scatter_plot(pDf,"figures/calibration/beta_05_05_s50/f")

# %% [markdown]
# # Mann Whitney

# %%
pDf = getdf(pmw_list5_2[1], 1000)
my_scatter_plot(pDf,"figures/calibration/beta_05_05_s50/mw")

# %% [markdown]
# # t-test

# %%
pDf = getdf(pt_list5_2[1], 1000)
my_scatter_plot(pDf,"figures/calibration/beta_05_05_s50/t")

# %% [markdown]
# # $|n|=|m|=100$

# %% [markdown]
# # Parallelized exact

# %%
pDf = getdf(pe_list_[2], 1000)
my_scatter_plot(pDf,"figures/calibration/beta_05_05_s100/e")

# %% [markdown]
# # Fast approximation

# %%
pDf = getdf(p_val_list_[2], 1000)
my_scatter_plot(pDf,"figures/calibration/beta_05_05_s100/f")

# %% [markdown]
# # Mann Whitney

# %%
pDf = getdf(pmw_list5_2[2], 1000)
my_scatter_plot(pDf,"figures/calibration/beta_05_05_s100/mw")

# %% [markdown]
# # t-test

# %%
pDf = getdf(pt_list5_2[2], 1000)
my_scatter_plot(pDf,"figures/calibration/beta_05_05_s100/t")

# %% [markdown]
# # $|n|=|m|=150$

# %% [markdown]
# # Parallelized exact

# %%
pDf = getdf(pe_list_[3], 1000)
my_scatter_plot(pDf,"figures/calibration/beta_05_05_s150/e")

# %% [markdown]
# # Fast approximation

# %%
pDf = getdf(p_val_list_[3], 1000)
my_scatter_plot(pDf,"figures/calibration/beta_05_05_s150/f")

# %% [markdown]
# # Mann whitney

# %%
pDf = getdf(pmw_list5_2[3], 1000)
my_scatter_plot(pDf,"figures/calibration/beta_05_05_s150/mw")

# %% [markdown]
# # t-test

# %%
pDf = getdf(pt_list5_2[3], 1000)
my_scatter_plot(pDf,"figures/calibration/beta_05_05_s150/t")

# %% [markdown]
# # $|n|=|m|=200$

# %% [markdown]
# # Parallelized exact

# %%
pDf = getdf(pe_list_[4], 1000)
my_scatter_plot(pDf,"figures/calibration/beta_05_05_s200/e")

# %% [markdown]
# # Fast approximation

# %%
pDf = getdf(p_val_list_[4], 1000)
my_scatter_plot(pDf,"figures/calibration/beta_05_05_s200/f")

# %% [markdown]
# # Mann Whitney

# %%
pDf = getdf(pmw_list5_2[4], 1000)
my_scatter_plot(pDf,"figures/calibration/beta_05_05_s200/mw")

# %% [markdown]
# # t-test

# %%
pDf = getdf(pt_list5_2[4], 1000)
my_scatter_plot(pDf,"figures/calibration/beta_05_05_s200/t")

# %% [markdown]
# # Calibration: with $X \sim \beta (2,5)$ and $Y\sim \beta(2,5)$

# %%
mean=2
sampleShape = [10,50, 100, 150, 200]

# %%
X_list_, y_list_, p_val_list_, time_listMc_ = loadMcResult(sampleShape, mean, path="dataFastPerm/uniform/beta_data")

# %%
pe_list_, TIME_ = shiftMethod(np.asarray(X_list_), np.asarray(y_list_), 40)

# %%
pmw_list5_2 = mannWhitney(np.asarray(X_list_), np.asarray(y_list_))

# %% [markdown]
# # $|n|=|m|=10$

# %% [markdown]
# # Parallelized exact

# %%
pDf = getdf(pe_list_[0], 1000)
my_scatter_plot(pDf,"figures/calibration/beta_2_5_s10/e")

# %% [markdown]
# # Fast approximation

# %%
pDf = getdf(p_val_list_[0], 1000)
my_scatter_plot(pDf,"figures/calibration/beta_2_5_s10/f")

# %% [markdown]
# # Mann Whitney

# %%
pDf = getdf(pmw_list5_2[0], 1000)
my_scatter_plot(pDf,"figures/calibration/beta_2_5_s10/mw")

# %% [markdown]
# # t-test

# %%
pDf = getdf(pt_list5_2[0], 1000)
my_scatter_plot(pDf,"figures/calibration/beta_2_5_s10/t")

# %% [markdown]
# # $|n|=|m|=50$

# %% [markdown]
# # Parallelized exact

# %%
pDf = getdf(pe_list_[1], 1000)
my_scatter_plot(pDf,"figures/calibration/beta_2_5_s50/e")

# %% [markdown]
# # Fast approximation

# %%
pDf = getdf(p_val_list_[1], 1000)
my_scatter_plot(pDf,"figures/calibration/beta_2_5_s50/f")

# %% [markdown]
# # Mann Whitney

# %%
pDf = getdf(pmw_list5_2[1], 1000)
my_scatter_plot(pDf,"figures/calibration/beta_2_5_s50/mw")

# %% [markdown]
# # t-test

# %%
pDf = getdf(pt_list5_2[1], 1000)
my_scatter_plot(pDf,"figures/calibration/beta_2_5_s50/t")

# %% [markdown]
# # $|n|=|m|=100$

# %% [markdown]
# # Parallelized exact

# %%
pDf = getdf(pe_list_[2], 1000)
my_scatter_plot(pDf,"figures/calibration/beta_2_5_s100/e")

# %% [markdown]
# # Fast approximation

# %%
pDf = getdf(p_val_list_[2], 1000)
my_scatter_plot(pDf,"figures/calibration/beta_2_5_s100/f")

# %% [markdown]
# # Mann Whitney

# %%
pDf = getdf(pmw_list5_2[2], 1000)
my_scatter_plot(pDf,"figures/calibration/beta_2_5_s100/mw")

# %% [markdown]
# # t-test

# %%
pDf = getdf(pt_list5_2[2], 1000)
my_scatter_plot(pDf,"figures/calibration/beta_2_5_s100/t")

# %% [markdown]
# # $|n|=|m|=150$

# %% [markdown]
# # Parallelized shift method

# %%
pDf = getdf(pe_list_[3], 1000)
my_scatter_plot(pDf,"figures/calibration/beta_2_5_s150/e")

# %% [markdown]
# # Fast approximations

# %%
pDf = getdf(p_val_list_[3], 1000)
my_scatter_plot(pDf,"figures/calibration/beta_2_5_s150/f")

# %% [markdown]
# # Mann Whitney

# %%
pDf = getdf(pmw_list5_2[3], 1000)
my_scatter_plot(pDf,"figures/calibration/beta_2_5_s150/mw")

# %% [markdown]
# # t-test

# %%
pDf = getdf(pt_list5_2[3], 1000)
my_scatter_plot(pDf,"figures/calibration/beta_2_5_s150/t")

# %% [markdown]
# # $|n|=|m|=200$

# %% [markdown]
# # Parallelized exact method

# %%
pDf = getdf(pe_list_[4], 1000)
my_scatter_plot(pDf,"figures/calibration/beta_2_5_s200/e")

# %% [markdown]
# # Fast approximation

# %%
pDf = getdf(p_val_list_[4], 1000)
my_scatter_plot(pDf,"figures/calibration/beta_2_5_s200/f")

# %% [markdown]
# # Mann Whitney

# %%
pDf = getdf(pmw_list5_2[4], 1000)
my_scatter_plot(pDf,"figures/calibration/beta_2_5_s200/mw")

# %% [markdown]
# # t-test

# %%
pDf = getdf(pt_list5_2[4], 1000)
my_scatter_plot(pDf,"figures/calibration/beta_2_5_s200/t")
