# %%
import pandas as pd
import numpy as np
from significance_of_mean_cuda import significance_of_mean_cuda
import time
from utils import MW, ttests, qvalues
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from scipy.stats import mannwhitneyu, ttest_ind

# %%
# %load_ext cython
# %load_ext rpy2.ipython
# Out:
# R[write to console]: Warning:
# R[write to console]:  namespace ‘pbdZMQ’ is not available and has been replaced
# by .GlobalEnv when processing object ‘.pbd_env’
#
# /home/ekvall/anaconda3/envs/my-r-env/lib/python3.7/site-packages/rpy2/robjects/pandas2ri.py:14: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import Index as PandasIndex
# /home/ekvall/anaconda3/envs/my-r-env/lib/python3.7/site-packages/rpy2/robjects/pandas2ri.py:34: UserWarning: pandas >= 1.0 is not supported.
#   warnings.warn('pandas >= 1.0 is not supported.')

# %%
# %%R
#
# require(ggplot2)
# install.packages("devtools")
# library("devtools")
# install_github("bdsegal/fastPerm")
#
# library(fastPerm)
# Out:
# R[write to console]: Loading required package: ggplot2
#
# R[write to console]: Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/devtools_2.2.2.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 375464 bytes (366 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 366 KB
#
#
# R[write to console]:
#
# R[write to console]:
# R[write to console]: The downloaded source packages are in
# 	‘/tmp/RtmpmOqcK9/downloaded_packages’
# R[write to console]:
# R[write to console]:
#
# R[write to console]: Loading required package: usethis
#
# R[write to console]: Skipping install of 'fastPerm' from a github remote, the SHA1 (639f37e1) has not changed since last install.
#   Use `force = TRUE` to force installation

# %%
# !ls "./data/nature18003-s2/"
# Out:
# CPTAC_BC_SupplementaryTable01.xlsx  CPTAC_BC_SupplementaryTable03.xlsx

# %%
path = "./data/nature18003-s2/"

# %%
T1 = pd.read_excel(path + "CPTAC_BC_SupplementaryTable01.xlsx")
T3 = pd.read_excel(path + "CPTAC_BC_SupplementaryTable03.xlsx")

# %% [markdown]
# ## Extract important column headings

# %%
paiteint_id = T1.columns[0]
stats_col = T1.columns[5: 5 + 3]

# %% [markdown]
# ### Patient column

# %%
paiteint_id
# Out:
# 'Sample ID'

# %% [markdown]
# ### Cancer phenotype coulmns

# %%
stats_col
# Out:
# Index(['ER Status', 'PR Status', 'HER2 Status'], dtype='object')

# %% [markdown]
# ### Check viable phenotype status

# %%
all_lab = list()
for r in T1[stats_col].iterrows():
    all_lab += list(r[1].values)

# %%
list(set(all_lab))
# Out:
# ['Negative', 'Indeterminate', 'Positive', 'Equivocal']

# %% [markdown]
# ### Let's drop patient with "Equivocal" and "Indeterminate" status

# %%
drop_label = ['Indeterminate', 'Equivocal']

# %%
T1.head()
# Out:
#   Sample ID       TCGA ID     Biospecimen Barcode Side  \
# 0   A2-A0CM  TCGA-A2-A0CM  TCGA-A2-A0CM-01A-11-A21V-30
# 1   A2-A0D2  TCGA-A2-A0D2  TCGA-A2-A0D2-01A-12-A21W-30
# 2   A2-A0EQ  TCGA-A2-A0EQ  TCGA-A2-A0EQ-01A-41-A21W-30
# 3   A2-A0EV  TCGA-A2-A0EV  TCGA-A2-A0EV-01A-41-A21V-30
# 4   A2-A0EX  TCGA-A2-A0EX  TCGA-A2-A0EX-01A-41-A21V-30
#
#                                    UIUD  PAM50 ER Status PR Status  \
# 0  330F7598-824C-4CD6-9303-A27FE74A6695  Basal  Negative  Negative
# 1  308CCD79-C164-4397-92BC-A1CD243C8E7D  Basal  Negative  Negative
# 2  04217F65-2907-478B-B0C5-EB65370198DA   Her2  Negative  Negative
# 3  38F98E5F-7FA4-4C89-8D81-516CF865BEEB   LumA  Positive  Positive
# 4  78271500-147B-40C5-B789-0CF0C7CDBCE2   LumA  Positive  Positive
#
#   HER2 Status QC Status  Proteome Cluster (see Fig. 3b)  ...  \
# 0    Negative      pass                             1.0  ...
# 1    Negative      pass                             1.0  ...
# 2    Positive      pass                             1.0  ...
# 3    Negative      pass                             3.0  ...
# 4    Negative      pass                             3.0  ...
#
#    iTRAQReporterIon  CommonControl GATA3 Mutation  \
# 0               116            YES            NaN
# 1               114             NO            NaN
# 2               116             NO            NaN
# 3               114             NO            NaN
# 4               116             NO            NaN
#
#                              PIK3CA Mutation  \
# 0                                        NaN
# 1                                        NaN
# 2         Missense_Mutation|Somatic|p.H1047R
# 3  In_Frame_Ins|Somatic|p.E469in_frame_insDK
# 4          Missense_Mutation|Somatic|p.E545K
#
#                                TP53 Mutation  \
# 0           Frame_Shift_Del|Somatic|p.E204fs
# 1           Frame_Shift_Del|Somatic|p.P318fs
# 2  In_Frame_Del|Somatic|p.IY162in_frame_delN
# 3                                        NaN
# 4                                        NaN
#
#   PIK3CA missense mutation in helical domain all tumors  \
# 0                                                0.0
# 1                                                0.0
# 2                                                NaN
# 3                                                NaN
# 4                                                1.0
#
#   PIK3CA missense mutation in kinase domain all tumors  \
# 0                                                0.0
# 1                                                0.0
# 2                                                1.0
# 3                                                NaN
# 4                                                NaN
#
#   TP53 Nonsense/Frameshift all tumors TP53 Missense mutation all tumors  \
# 0                                 1.0                               NaN
# 1                                 1.0                               NaN
# 2                                 NaN                               NaN
# 3                                 0.0                               0.0
# 4                                 0.0                               0.0
#
#    TP53 missense mutations in DNA binding domain all tumors
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                0.0
# 4                                                0.0
#
# [5 rows x 24 columns]

# %%
mask1 = [True if (len(set(r[1].values) & set(drop_label)) == 0) else False for r in T1[stats_col].iterrows()]
T1 = T1[mask1]
T1.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### Let's divide the dataframe into two dataframes with triple negative (TN) and non-triple negative (NTN)

# %%
mask2 = [all([True if v=='Negative' else False for v in r[1].values] ) for r in T1[stats_col].iterrows()]

T1_TNP = T1[np.array(mask2)]
T1_TNP.reset_index(drop=True, inplace=True)

T1_not_TNP = T1[~np.array(mask2)]
T1_not_TNP.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### Obtain patient ids for NT and NTN

# %%
TNPpateintIds = T1_TNP[paiteint_id].values
NotTNPpateintIds = T1_not_TNP[paiteint_id].values

# %% [markdown]
# ### Remove genes (rows) containing NaN for both TN and NTN i.e., make sure all patients have same the gene when comparing.

# %%
def getpatientId(ids):
    patitentList = list()
    for i in ids:
        p_id = T3[T3.columns[[i in c for c in T3.columns]]].columns
        patitentList += list(p_id)
    return patitentList

# %%
only_patientDf = T3[getpatientId(NotTNPpateintIds) + getpatientId(TNPpateintIds)]

# %%
only_patientDf.dropna(inplace=True)
# Out:
# /home/ekvall/anaconda3/envs/my-r-env/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
NotTNP_df =  only_patientDf[getpatientId(NotTNPpateintIds)]
TNP_df =  only_patientDf[getpatientId(TNPpateintIds)]

# %%
NotTNP_Arr, TNP_Arr =NotTNP_df.values, TNP_df.values

# %%
NotTNP_Arr.shape
# Out:
# (8051, 80)

# %%
TNP_Arr.shape
# Out:
# (8051, 26)

# %%
#NotTNP_df.to_csv("data/notTNPdf")
#TNP_df.to_csv("data/TNPdf")

# %% [markdown]
# ### There are 80 patients without triple negative (NTN) and 26 patients with triple negtive (TN), and with a total of 8051 quantified genes.

# %% [markdown]
# # Experiment time

# %% [markdown]
# ## Let's start with a rather small binsize=6.

# %%
start = time.time()

SGM = significance_of_mean_cuda(6, dtype_v=np.uint32,dtype_A=np.float64)
SGM.run(TNP_Arr, NotTNP_Arr)
P_e_list = list(1 - SGM.p_values)

end = time.time()
print(end - start)
# Out:
# 1.9656782150268555

# %%
x = pd.DataFrame(TNP_Arr, columns=list(range(TNP_Arr.shape[1]))).T
y = pd.DataFrame(NotTNP_Arr, columns=list(range(NotTNP_Arr.shape[1]))).T
n_samples = x.shape[1]
outputDf = pd.DataFrame(n_samples * [0], columns=["output"]).T

# %%
# %R -i x
# %R -i y
# %R -i outputDf
# %R -i n_samples

# %%
# %%R
# runFastPerm <- function(x,y,output, n_samples) {
#     e <- list(mode="vector",length=n_samples)
#         for (i in 1:n_samples) {
#
#             mStopDiffMean(x[[i]], y[[i]])
#             valX = fastPerm(x[[i]], y[[i]], testStat = diffMean)
#
#             print(valX)
#             valX <-unlist(valX)
#
#
#             output[[i]] <- as.numeric(valX[1])
#
#             }
#
#
#     return(output)
#
#
# }

# %%
start = time.time()
# %R out <- runFastPerm(x,y, outputDf, n_samples)
end = time.time()
print(end - start)
# Out:
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0769
# p-value = 0.797
# mStop = 20, deviance = 190, AIC = 372
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0734
# p-value = 0.804
# mStop = 20, deviance = 182, AIC = 364
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0706
# p-value = 0.815
# mStop = 20, deviance = 175, AIC = 357
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.076
# p-value = 0.796
# mStop = 20, deviance = 221, AIC = 403
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0742
# p-value = 0.803
# mStop = 20, deviance = 210, AIC = 392
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.073
# p-value = 0.799
# mStop = 20, deviance = 181, AIC = 363
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0741
# p-value = 0.796
# mStop = 20, deviance = 184, AIC = 366
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0742
# p-value = 0.798
# mStop = 20, deviance = 201, AIC = 382
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0865
# p-value = 0.847
# mStop = 20, deviance = 103, AIC = 286
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 1.56
# p-value = 1.53e-07
# mStop = 12, deviance = 194, AIC = 254
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 1.14
# p-value = 0.000158
# mStop = 17, deviance = 300, AIC = 390
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.477
# p-value = 0.00796
# mStop = 20, deviance = 385, AIC = 514
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.4
# p-value = 0.0683
# mStop = 20, deviance = 460, AIC = 611
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.52
# p-value = 0.0474
# mStop = 20, deviance = 409, AIC = 557
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.702
# p-value = 0.0997
# mStop = 20, deviance = 477, AIC = 633
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.398
# p-value = 0.233
# mStop = 20, deviance = 572, AIC = 736
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.477
# p-value = 0.0468
# mStop = 20, deviance = 370, AIC = 518
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 1.36
# p-value = 0.000648
# mStop = 17, deviance = 342, AIC = 441
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.092
# p-value = 0.778
# mStop = 20, deviance = 271, AIC = 451
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0862
# p-value = 0.795
# mStop = 20, deviance = 280, AIC = 461
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.682
# p-value = 0.0127
# mStop = 20, deviance = 334, AIC = 469
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0871
# p-value = 0.795
# mStop = 20, deviance = 253, AIC = 434
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0696
# p-value = 0.838
# mStop = 20, deviance = 181, AIC = 363
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.435
# p-value = 0.477
# mStop = 20, deviance = 429, AIC = 602
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.428
# p-value = 0.45
# mStop = 20, deviance = 494, AIC = 665
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.993
# p-value = 0.00158
# mStop = 20, deviance = 293, AIC = 406
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0589
# p-value = 0.84
# mStop = 20, deviance = 139, AIC = 322
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 1.03
# p-value = 1.8e-05
# mStop = 14, deviance = 239, AIC = 315
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.898
# p-value = 0.0013
# mStop = 19, deviance = 302, AIC = 408
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.558
# p-value = 0.273
# mStop = 20, deviance = 489, AIC = 656
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.784
# p-value = 0.145
# mStop = 20, deviance = 487, AIC = 646
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.684
# p-value = 0.174
# mStop = 20, deviance = 539, AIC = 700
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.704
# p-value = 0.176
# mStop = 20, deviance = 513, AIC = 675
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.926
# p-value = 0.0843
# mStop = 20, deviance = 459, AIC = 613
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.879
# p-value = 0.097
# mStop = 20, deviance = 463, AIC = 618
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.282
# p-value = 0.298
# mStop = 20, deviance = 538, AIC = 705
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0554
# p-value = 0.854
# mStop = 20, deviance = 123, AIC = 306
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.949
# p-value = 0.0994
# mStop = 20, deviance = 508, AIC = 663
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.491
# p-value = 0.0137
# mStop = 20, deviance = 329, AIC = 464
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.101
# p-value = 0.733
# mStop = 20, deviance = 185, AIC = 365
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.977
# p-value = 0.0533
# mStop = 20, deviance = 337, AIC = 487
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0565
# p-value = 0.843
# mStop = 20, deviance = 134, AIC = 317
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.964
# p-value = 0.0556
# mStop = 20, deviance = 319, AIC = 469
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.119
# p-value = 0.767
# mStop = 20, deviance = 281, AIC = 461
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.121
# p-value = 0.763
# mStop = 20, deviance = 240, AIC = 420
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0388
# p-value = 0.899
# mStop = 20, deviance = 100, AIC = 285
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.481
# p-value = 0.0372
# mStop = 20, deviance = 381, AIC = 527
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.795
# p-value = 0.0186
# mStop = 20, deviance = 380, AIC = 519
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.801
# p-value = 0.0182
# mStop = 20, deviance = 364, AIC = 503
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.74
# p-value = 0.000591
# mStop = 18, deviance = 306, AIC = 404
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.731
# p-value = 0.000478
# mStop = 19, deviance = 287, AIC = 387
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.724
# p-value = 0.000977
# mStop = 19, deviance = 329, AIC = 432
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.307
# p-value = 0.272
# mStop = 20, deviance = 509, AIC = 675
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0465
# p-value = 0.929
# mStop = 20, deviance = 49.7, AIC = 235
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.147
# p-value = 0.632
# mStop = 20, deviance = 307, AIC = 485
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.128
# p-value = 0.652
# mStop = 20, deviance = 346, AIC = 524
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.489
# p-value = 0.0328
# mStop = 20, deviance = 400, AIC = 545
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 1.19
# p-value = 0.00271
# mStop = 20, deviance = 333, AIC = 453
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.623
# p-value = 0.0477
# mStop = 20, deviance = 333, AIC = 481
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.898
# p-value = 0.00443
# mStop = 20, deviance = 397, AIC = 522
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.89
# p-value = 0.00405
# mStop = 20, deviance = 379, AIC = 504
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.172
# p-value = 0.598
# mStop = 20, deviance = 285, AIC = 461
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.165
# p-value = 0.606
# mStop = 20, deviance = 270, AIC = 447
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.871
# p-value = 8.95e-05
# mStop = 15, deviance = 278, AIC = 362
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.894
# p-value = 7.43e-05
# mStop = 15, deviance = 255, AIC = 338
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 1.2
# p-value = 0.0109
# mStop = 20, deviance = 361, AIC = 494
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.708
# p-value = 0.0223
# mStop = 20, deviance = 457, AIC = 597
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 1.2
# p-value = 0.0112
# mStop = 20, deviance = 383, AIC = 515
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.926
# p-value = 0.000372
# mStop = 16, deviance = 297, AIC = 390
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.495
# p-value = 0.108
# mStop = 20, deviance = 470, AIC = 627
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.523
# p-value = 0.0964
# mStop = 20, deviance = 500, AIC = 655
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.519
# p-value = 0.107
# mStop = 20, deviance = 499, AIC = 655
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.403
# p-value = 0.0401
# mStop = 20, deviance = 418, AIC = 565
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.398
# p-value = 0.0462
# mStop = 20, deviance = 428, AIC = 576
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.555
# p-value = 0.0735
# mStop = 20, deviance = 436, AIC = 589
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.142
# p-value = 0.712
# mStop = 20, deviance = 322, AIC = 501
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.14
# p-value = 0.733
# mStop = 20, deviance = 296, AIC = 476
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.494
# p-value = 0.00207
# mStop = 20, deviance = 339, AIC = 453
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.612
# p-value = 0.00277
# mStop = 20, deviance = 292, AIC = 412
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0381
# p-value = 0.915
# mStop = 20, deviance = 53.2, AIC = 238
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.289
# p-value = 0.0815
# mStop = 20, deviance = 482, AIC = 636
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0409
# p-value = 0.95
# mStop = 20, deviance = 16.1, AIC = 202
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 1.04
# p-value = 0.000247
# mStop = 16, deviance = 336, AIC = 427
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.285
# p-value = 0.15
# mStop = 20, deviance = 543, AIC = 702
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.142
# p-value = 0.532
# mStop = 20, deviance = 445, AIC = 619
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.138
# p-value = 0.717
# mStop = 20, deviance = 275, AIC = 454
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.163
# p-value = 0.502
# mStop = 20, deviance = 471, AIC = 644
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.176
# p-value = 0.592
# mStop = 20, deviance = 389, AIC = 565
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0281
# p-value = 0.931
# mStop = 20, deviance = 49.8, AIC = 235
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.272
# p-value = 0.296
# mStop = 20, deviance = 475, AIC = 642
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.941
# p-value = 0.00744
# mStop = 20, deviance = 487, AIC = 614
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0669
# p-value = 0.857
# mStop = 20, deviance = 119, AIC = 303
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 1.92
# p-value = 7.91e-06
# mStop = 14, deviance = 200, AIC = 274
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.467
# p-value = 0.254
# mStop = 20, deviance = 527, AIC = 692
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.465
# p-value = 0.253
# mStop = 20, deviance = 537, AIC = 702
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.458
# p-value = 0.265
# mStop = 20, deviance = 518, AIC = 684
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.356
# p-value = 0.148
# mStop = 20, deviance = 523, AIC = 682
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 1.65
# p-value = 0.000327
# mStop = 16, deviance = 329, AIC = 419
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 1.71
# p-value = 5.4e-05
# mStop = 13, deviance = 257, AIC = 333
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 1.76
# p-value = 1.05e-05
# mStop = 12, deviance = 246, AIC = 315
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.762
# p-value = 0.0341
# mStop = 20, deviance = 395, AIC = 539
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.335
# p-value = 0.325
# mStop = 20, deviance = 508, AIC = 676
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.147
# p-value = 0.797
# mStop = 20, deviance = 212, AIC = 394
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.219
# p-value = 0.145
# mStop = 20, deviance = 473, AIC = 633
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.046
# p-value = 0.814
# mStop = 20, deviance = 178, AIC = 360
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 1.24
# p-value = 0.0239
# mStop = 20, deviance = 363, AIC = 504
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.387
# p-value = 0.231
# mStop = 20, deviance = 529, AIC = 693
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.164
# p-value = 0.554
# mStop = 20, deviance = 344, AIC = 519
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0911
# p-value = 0.368
# mStop = 20, deviance = 459, AIC = 628
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.133
# p-value = 0.773
# mStop = 20, deviance = 187, AIC = 368
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.22
# p-value = 0.629
# mStop = 20, deviance = 353, AIC = 530
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.212
# p-value = 0.166
# mStop = 20, deviance = 519, AIC = 680
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.369
# p-value = 0.0443
# mStop = 20, deviance = 487, AIC = 634
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.26
# p-value = 0.143
# mStop = 20, deviance = 525, AIC = 684
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.526
# p-value = 0.105
# mStop = 20, deviance = 487, AIC = 642
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.667
# p-value = 0.0347
# mStop = 20, deviance = 422, AIC = 566
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0616
# p-value = 0.899
# mStop = 20, deviance = 70.8, AIC = 255
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.158
# p-value = 0.604
# mStop = 20, deviance = 358, AIC = 534
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.161
# p-value = 0.596
# mStop = 20, deviance = 353, AIC = 529
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 1.01
# p-value = 0.00327
# mStop = 20, deviance = 355, AIC = 476
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.3
# p-value = 0.478
# mStop = 20, deviance = 460, AIC = 632
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.202
# p-value = 0.265
# mStop = 20, deviance = 531, AIC = 697
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.394
# p-value = 0.0962
# mStop = 20, deviance = 475, AIC = 630
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.607
# p-value = 0.0386
# mStop = 20, deviance = 439, AIC = 585
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.192
# p-value = 0.697
# mStop = 20, deviance = 303, AIC = 482
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0676
# p-value = 0.872
# mStop = 20, deviance = 99.8, AIC = 284
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.197
# p-value = 0.0945
# mStop = 20, deviance = 548, AIC = 702
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.353
# p-value = 0.49
# mStop = 20, deviance = 490, AIC = 662
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.97
# p-value = 0.0672
# mStop = 20, deviance = 439, AIC = 590
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.891
# p-value = 0.0934
# mStop = 20, deviance = 484, AIC = 638
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.783
# p-value = 0.00562
# mStop = 20, deviance = 317, AIC = 443
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.761
# p-value = 0.0912
# mStop = 20, deviance = 446, AIC = 601
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.409
# p-value = 0.431
# mStop = 20, deviance = 494, AIC = 666
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0401
# p-value = 0.831
# mStop = 20, deviance = 152, AIC = 334
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 1.71
# p-value = 9.44e-11
# mStop = 7, deviance = 96.5, AIC = 137
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 1.72
# p-value = 4.7e-11
# mStop = 8, deviance = 99.5, AIC = 142
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 1.17
# p-value = 0.000751
# mStop = 16, deviance = 352, AIC = 448
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.358
# p-value = 0.172
# mStop = 20, deviance = 499, AIC = 660
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.251
# p-value = 0.255
# mStop = 20, deviance = 705, AIC = 869
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.601
# p-value = 0.305
# mStop = 20, deviance = 473, AIC = 641
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.761
# p-value = 0.00552
# mStop = 20, deviance = 330, AIC = 457
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.754
# p-value = 0.0066
# mStop = 20, deviance = 409, AIC = 538
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 1.17
# p-value = 6.36e-05
# mStop = 14, deviance = 197, AIC = 278
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 1.15
# p-value = 8.81e-05
# mStop = 16, deviance = 215, AIC = 301
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.475
# p-value = 0.207
# mStop = 20, deviance = 566, AIC = 729
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.474
# p-value = 0.211
# mStop = 20, deviance = 577, AIC = 740
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.483
# p-value = 0.206
# mStop = 20, deviance = 588, AIC = 751
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.503
# p-value = 0.137
# mStop = 20, deviance = 502, AIC = 661
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.267
# p-value = 0.0362
# mStop = 20, deviance = 405, AIC = 551
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 1.5
# p-value = 7.09e-05
# mStop = 15, deviance = 216, AIC = 297
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.979
# p-value = 0.0176
# mStop = 20, deviance = 399, AIC = 537
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.178
# p-value = 0.273
# mStop = 20, deviance = 537, AIC = 703
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.42
# p-value = 0.293
# mStop = 20, deviance = 540, AIC = 706
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.378
# p-value = 0.175
# mStop = 20, deviance = 516, AIC = 677
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.438
# p-value = 0.342
# mStop = 20, deviance = 520, AIC = 688
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.394
# p-value = 0.325
# mStop = 20, deviance = 526, AIC = 694
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.186
# p-value = 0.604
# mStop = 20, deviance = 284, AIC = 461
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.263
# p-value = 0.149
# mStop = 20, deviance = 503, AIC = 662
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.33
# p-value = 0.0652
# mStop = 20, deviance = 470, AIC = 621
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.191
# p-value = 0.181
# mStop = 20, deviance = 504, AIC = 665
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0405
# p-value = 0.791
# mStop = 20, deviance = 202, AIC = 383
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.012
# p-value = 0.949
# mStop = 20, deviance = 18.4, AIC = 205
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.411
# p-value = 0.00328
# mStop = 18, deviance = 277, AIC = 387
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.955
# p-value = 0.0619
# mStop = 20, deviance = 476, AIC = 627
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.844
# p-value = 0.00204
# mStop = 20, deviance = 287, AIC = 406
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.496
# p-value = 0.102
# mStop = 20, deviance = 531, AIC = 686
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.544
# p-value = 0.00194
# mStop = 17, deviance = 305, AIC = 409
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 1.36
# p-value = 0.0433
# mStop = 20, deviance = 381, AIC = 528
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.00932
# p-value = 0.976
# mStop = 20, deviance = 6.46, AIC = 193
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.58
# p-value = 0.115
# mStop = 20, deviance = 480, AIC = 637
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.865
# p-value = 0.0394
# mStop = 20, deviance = 443, AIC = 589
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.888
# p-value = 0.0288
# mStop = 20, deviance = 441, AIC = 583
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 1.37
# p-value = 0.00101
# mStop = 20, deviance = 297, AIC = 406
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 1.27
# p-value = 0.000294
# mStop = 17, deviance = 302, AIC = 395
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.738
# p-value = 0.00153
# mStop = 20, deviance = 305, AIC = 414
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 1.54
# p-value = 1.76e-05
# mStop = 14, deviance = 227, AIC = 303
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.303
# p-value = 0.285
# mStop = 20, deviance = 405, AIC = 572
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.252
# p-value = 0.0634
# mStop = 20, deviance = 374, AIC = 525
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.729
# p-value = 0.00194
# mStop = 20, deviance = 302, AIC = 419
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.732
# p-value = 0.00181
# mStop = 20, deviance = 284, AIC = 397
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.996
# p-value = 1.51e-08
# mStop = 9, deviance = 86, AIC = 136
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.788
# p-value = 0.00319
# mStop = 20, deviance = 385, AIC = 503
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.92
# p-value = 0.000193
# mStop = 16, deviance = 299, AIC = 388
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.918
# p-value = 4.11e-06
# mStop = 12, deviance = 217, AIC = 284
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.197
# p-value = 0.461
# mStop = 20, deviance = 461, AIC = 633
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.366
# p-value = 0.127
# mStop = 20, deviance = 525, AIC = 683
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.391
# p-value = 0.282
# mStop = 20, deviance = 583, AIC = 749
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.293
# p-value = 0.0109
# mStop = 20, deviance = 374, AIC = 508
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.315
# p-value = 0.399
# mStop = 20, deviance = 515, AIC = 686
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.417
# p-value = 0.158
# mStop = 20, deviance = 524, AIC = 684
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.275
# p-value = 0.0785
# mStop = 20, deviance = 456, AIC = 609
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.278
# p-value = 0.0716
# mStop = 20, deviance = 431, AIC = 584
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.23
# p-value = 0.589
# mStop = 20, deviance = 353, AIC = 529
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 1.09
# p-value = 0.000227
# mStop = 17, deviance = 306, AIC = 399
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.016
# p-value = 0.971
# mStop = 20, deviance = 9.08, AIC = 196
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.811
# p-value = 0.000464
# mStop = 17, deviance = 317, AIC = 411
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.499
# p-value = 0.00241
# mStop = 20, deviance = 324, AIC = 442
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.501
# p-value = 0.000624
# mStop = 16, deviance = 302, AIC = 396
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0414
# p-value = 0.912
# mStop = 20, deviance = 71.7, AIC = 257
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.488
# p-value = 0.237
# mStop = 20, deviance = 510, AIC = 675
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.206
# p-value = 0.626
# mStop = 20, deviance = 264, AIC = 442
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0738
# p-value = 0.78
# mStop = 20, deviance = 191, AIC = 372
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.728
# p-value = 0.011
# mStop = 20, deviance = 366, AIC = 499
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.801
# p-value = 0.00296
# mStop = 20, deviance = 322, AIC = 440
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0466
# p-value = 0.854
# mStop = 20, deviance = 126, AIC = 309
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.564
# p-value = 0.0912
# mStop = 20, deviance = 597, AIC = 751
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.564
# p-value = 0.436
# mStop = 20, deviance = 437, AIC = 609
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.241
# p-value = 0.506
# mStop = 20, deviance = 449, AIC = 622
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.191
# p-value = 0.483
# mStop = 20, deviance = 472, AIC = 645
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.216
# p-value = 0.432
# mStop = 20, deviance = 520, AIC = 691
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.223
# p-value = 0.429
# mStop = 20, deviance = 539, AIC = 709
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 1.18
# p-value = 0.0154
# mStop = 20, deviance = 359, AIC = 496
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 1.18
# p-value = 0.0136
# mStop = 20, deviance = 342, AIC = 477
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.257
# p-value = 0.316
# mStop = 20, deviance = 486, AIC = 654
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.281
# p-value = 0.293
# mStop = 20, deviance = 495, AIC = 662
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.33
# p-value = 0.248
# mStop = 20, deviance = 542, AIC = 707
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.238
# p-value = 0.409
# mStop = 20, deviance = 429, AIC = 600
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.245
# p-value = 0.407
# mStop = 20, deviance = 445, AIC = 616
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.256
# p-value = 0.361
# mStop = 20, deviance = 421, AIC = 591
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.13
# p-value = 0.606
# mStop = 20, deviance = 310, AIC = 487
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.104
# p-value = 0.682
# mStop = 20, deviance = 340, AIC = 518
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0734
# p-value = 0.738
# mStop = 20, deviance = 209, AIC = 389
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.644
# p-value = 0.000588
# mStop = 16, deviance = 245, AIC = 340
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.563
# p-value = 0.0782
# mStop = 20, deviance = 388, AIC = 541
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0648
# p-value = 0.527
# mStop = 20, deviance = 365, AIC = 540
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.701
# p-value = 0.000184
# mStop = 15, deviance = 282, AIC = 368
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.122
# p-value = 0.74
# mStop = 20, deviance = 195, AIC = 376
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.133
# p-value = 0.726
# mStop = 20, deviance = 210, AIC = 390
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 1.14
# p-value = 0.0239
# mStop = 20, deviance = 274, AIC = 416
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.21
# p-value = 0.121
# mStop = 20, deviance = 508, AIC = 665
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.545
# p-value = 0.0659
# mStop = 20, deviance = 495, AIC = 646
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.437
# p-value = 0.159
# mStop = 20, deviance = 492, AIC = 653
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.237
# p-value = 0.563
# mStop = 20, deviance = 374, AIC = 549
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.158
# p-value = 0.741
# mStop = 20, deviance = 190, AIC = 371
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.657
# p-value = 0.0752
# mStop = 20, deviance = 507, AIC = 659
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.028
# p-value = 0.92
# mStop = 20, deviance = 49.9, AIC = 235
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.818
# p-value = 0.00595
# mStop = 20, deviance = 443, AIC = 570
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.795
# p-value = 0.00697
# mStop = 20, deviance = 449, AIC = 577
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 1.33
# p-value = 0.000688
# mStop = 16, deviance = 304, AIC = 399
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.51
# p-value = 0.106
# mStop = 20, deviance = 467, AIC = 624
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0144
# p-value = 0.972
# mStop = 20, deviance = 9.12, AIC = 196
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.898
# p-value = 0.000224
# mStop = 17, deviance = 315, AIC = 407
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.62
# p-value = 0.108
# mStop = 20, deviance = 488, AIC = 644
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.892
# p-value = 0.0118
# mStop = 20, deviance = 370, AIC = 504
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.152
# p-value = 0.337
# mStop = 20, deviance = 504, AIC = 673
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.579
# p-value = 0.00252
# mStop = 20, deviance = 350, AIC = 468
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.705
# p-value = 0.0447
# mStop = 20, deviance = 441, AIC = 589
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.574
# p-value = 0.00481
# mStop = 20, deviance = 325, AIC = 449
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.273
# p-value = 0.142
# mStop = 20, deviance = 589, AIC = 748
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.106
# p-value = 0.628
# mStop = 20, deviance = 334, AIC = 511
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 1.76
# p-value = 5.53e-08
# mStop = 11, deviance = 139, AIC = 195
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.342
# p-value = 0.0902
# mStop = 20, deviance = 562, AIC = 716
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.253
# p-value = 0.638
# mStop = 20, deviance = 291, AIC = 469
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0137
# p-value = 0.982
# mStop = 20, deviance = 7.92, AIC = 195
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.649
# p-value = 0.0623
# mStop = 20, deviance = 470, AIC = 621
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.075
# p-value = 0.716
# mStop = 20, deviance = 301, AIC = 480
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0885
# p-value = 0.668
# mStop = 20, deviance = 332, AIC = 510
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.111
# p-value = 0.519
# mStop = 20, deviance = 418, AIC = 592
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.332
# p-value = 0.039
# mStop = 20, deviance = 414, AIC = 560
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.107
# p-value = 0.441
# mStop = 20, deviance = 464, AIC = 635
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.526
# p-value = 0.00572
# mStop = 20, deviance = 375, AIC = 502
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0371
# p-value = 0.884
# mStop = 20, deviance = 74.2, AIC = 258
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.23
# p-value = 0.594
# mStop = 20, deviance = 488, AIC = 663
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.795
# p-value = 0.0229
# mStop = 20, deviance = 540, AIC = 679
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 1.76
# p-value = 0.000149
# mStop = 14, deviance = 281, AIC = 363
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.273
# p-value = 0.292
# mStop = 20, deviance = 500, AIC = 667
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.188
# p-value = 0.486
# mStop = 20, deviance = 446, AIC = 619
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0985
# p-value = 0.327
# mStop = 20, deviance = 516, AIC = 684
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0989
# p-value = 0.323
# mStop = 20, deviance = 537, AIC = 705
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0944
# p-value = 0.356
# mStop = 20, deviance = 488, AIC = 657
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.202
# p-value = 0.048
# mStop = 20, deviance = 378, AIC = 527
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 1.52
# p-value = 0.00221
# mStop = 20, deviance = 418, AIC = 533
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.353
# p-value = 0.242
# mStop = 20, deviance = 502, AIC = 667
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 1.71
# p-value = 5.63e-05
# mStop = 15, deviance = 262, AIC = 344
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.731
# p-value = 0.263
# mStop = 20, deviance = 544, AIC = 710
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 1.22
# p-value = 0.0129
# mStop = 20, deviance = 377, AIC = 512
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.646
# p-value = 0.152
# mStop = 20, deviance = 447, AIC = 607
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 2.82
# p-value = 0.000108
# mStop = 17, deviance = 269, AIC = 358
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.313
# p-value = 0.347
# mStop = 20, deviance = 438, AIC = 608
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.437
# p-value = 0.166
# mStop = 20, deviance = 473, AIC = 634
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 2.77
# p-value = 0.000361
# mStop = 17, deviance = 213, AIC = 306
# ...
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.103
# p-value = 0.661
# mStop = 20, deviance = 312, AIC = 489
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0564
# p-value = 0.822
# mStop = 20, deviance = 170, AIC = 352
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.966
# p-value = 0.101
# mStop = 20, deviance = 448, AIC = 604
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.317
# p-value = 0.432
# mStop = 20, deviance = 496, AIC = 667
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.105
# p-value = 0.853
# mStop = 20, deviance = 116, AIC = 299
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 3.29
# p-value = 0.000485
# mStop = 14, deviance = 272, AIC = 360
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.644
# p-value = 0.0757
# mStop = 20, deviance = 413, AIC = 566
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.278
# p-value = 0.538
# mStop = 20, deviance = 343, AIC = 518
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.391
# p-value = 0.123
# mStop = 20, deviance = 590, AIC = 747
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.89
# p-value = 0.0585
# mStop = 20, deviance = 417, AIC = 568
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.166
# p-value = 0.381
# mStop = 20, deviance = 523, AIC = 692
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.114
# p-value = 0.68
# mStop = 20, deviance = 323, AIC = 501
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.572
# p-value = 0.208
# mStop = 20, deviance = 497, AIC = 660
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.822
# p-value = 0.0106
# mStop = 20, deviance = 387, AIC = 519
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.467
# p-value = 0.461
# mStop = 20, deviance = 463, AIC = 636
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0784
# p-value = 0.87
# mStop = 20, deviance = 103, AIC = 287
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.761
# p-value = 0.279
# mStop = 20, deviance = 518, AIC = 684
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0309
# p-value = 0.969
# mStop = 20, deviance = 15.9, AIC = 202
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0977
# p-value = 0.673
# mStop = 20, deviance = 309, AIC = 487
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0682
# p-value = 0.644
# mStop = 20, deviance = 356, AIC = 533
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.261
# p-value = 0.595
# mStop = 20, deviance = 322, AIC = 499
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.134
# p-value = 0.472
# mStop = 20, deviance = 450, AIC = 622
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 1.3
# p-value = 0.0223
# mStop = 20, deviance = 370, AIC = 510
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.143
# p-value = 0.885
# mStop = 20, deviance = 106, AIC = 290
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.185
# p-value = 0.588
# mStop = 20, deviance = 338, AIC = 514
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.712
# p-value = 0.385
# mStop = 20, deviance = 451, AIC = 621
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0709
# p-value = 0.93
# mStop = 20, deviance = 47, AIC = 232
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.485
# p-value = 0.703
# mStop = 20, deviance = 228, AIC = 407
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.543
# p-value = 0.0636
# mStop = 20, deviance = 394, AIC = 546
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.272
# p-value = 0.234
# mStop = 20, deviance = 499, AIC = 664
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.209
# p-value = 0.685
# mStop = 20, deviance = 319, AIC = 497
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.184
# p-value = 0.707
# mStop = 20, deviance = 260, AIC = 439
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.111
# p-value = 0.691
# mStop = 20, deviance = 305, AIC = 484
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 1.05
# p-value = 0.199
# mStop = 20, deviance = 516, AIC = 679
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 1.55
# p-value = 0.0621
# mStop = 20, deviance = 451, AIC = 602
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 1.06
# p-value = 0.168
# mStop = 20, deviance = 504, AIC = 665
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 1.03
# p-value = 0.217
# mStop = 20, deviance = 496, AIC = 660
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 1.59
# p-value = 0.0688
# mStop = 20, deviance = 480, AIC = 631
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 2.7
# p-value = 0.00314
# mStop = 20, deviance = 319, AIC = 440
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0737
# p-value = 0.678
# mStop = 20, deviance = 290, AIC = 469
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.34
# p-value = 0.36
# mStop = 20, deviance = 540, AIC = 708
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.886
# p-value = 0.0621
# mStop = 20, deviance = 479, AIC = 630
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 1.95
# p-value = 4.19e-05
# mStop = 17, deviance = 309, AIC = 393
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.252
# p-value = 0.539
# mStop = 20, deviance = 399, AIC = 574
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.763
# p-value = 0.00337
# mStop = 20, deviance = 376, AIC = 497
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.108
# p-value = 0.869
# mStop = 20, deviance = 168, AIC = 351
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.108
# p-value = 0.891
# mStop = 20, deviance = 94.7, AIC = 279
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.644
# p-value = 0.0444
# mStop = 20, deviance = 374, AIC = 521
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.199
# p-value = 0.619
# mStop = 20, deviance = 349, AIC = 525
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0958
# p-value = 0.851
# mStop = 20, deviance = 120, AIC = 304
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.05
# p-value = 0.823
# mStop = 20, deviance = 150, AIC = 333
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.408
# p-value = 0.215
# mStop = 20, deviance = 546, AIC = 710
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.468
# p-value = 0.156
# mStop = 20, deviance = 530, AIC = 690
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.1
# p-value = 0.808
# mStop = 20, deviance = 178, AIC = 360
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.749
# p-value = 0.00606
# mStop = 20, deviance = 393, AIC = 521
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.307
# p-value = 0.324
# mStop = 20, deviance = 518, AIC = 686
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.449
# p-value = 0.0979
# mStop = 20, deviance = 491, AIC = 646
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.159
# p-value = 0.722
# mStop = 20, deviance = 262, AIC = 441
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.44
# p-value = 0.119
# mStop = 20, deviance = 487, AIC = 644
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0928
# p-value = 0.671
# mStop = 20, deviance = 353, AIC = 531
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.179
# p-value = 0.574
# mStop = 20, deviance = 392, AIC = 568
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 1.63
# p-value = 0.059
# mStop = 20, deviance = 438, AIC = 588
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.644
# p-value = 0.0618
# mStop = 20, deviance = 514, AIC = 664
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0868
# p-value = 0.705
# mStop = 20, deviance = 246, AIC = 426
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.807
# p-value = 0.299
# mStop = 20, deviance = 498, AIC = 665
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0147
# p-value = 0.97
# mStop = 20, deviance = 10.9, AIC = 198
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.1
# p-value = 0.789
# mStop = 20, deviance = 215, AIC = 396
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.45
# p-value = 0.686
# mStop = 20, deviance = 284, AIC = 462
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.439
# p-value = 0.0451
# mStop = 20, deviance = 400, AIC = 548
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.108
# p-value = 0.714
# mStop = 20, deviance = 291, AIC = 470
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0147
# p-value = 0.981
# mStop = 20, deviance = 3.91, AIC = 191
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.132
# p-value = 0.763
# mStop = 20, deviance = 216, AIC = 396
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.437
# p-value = 0.0714
# mStop = 20, deviance = 390, AIC = 542
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.975
# p-value = 0.00213
# mStop = 20, deviance = 288, AIC = 406
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.462
# p-value = 0.29
# mStop = 20, deviance = 578, AIC = 744
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 1.05
# p-value = 0.334
# mStop = 20, deviance = 500, AIC = 668
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0773
# p-value = 0.888
# mStop = 20, deviance = 74, AIC = 258
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 1.68
# p-value = 5.47e-07
# mStop = 12, deviance = 169, AIC = 232
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.443
# p-value = 0.277
# mStop = 20, deviance = 523, AIC = 689
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0207
# p-value = 0.969
# mStop = 20, deviance = 9.11, AIC = 196
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0282
# p-value = 0.972
# mStop = 20, deviance = 12.4, AIC = 199
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.297
# p-value = 0.233
# mStop = 20, deviance = 489, AIC = 653
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.194
# p-value = 0.821
# mStop = 20, deviance = 151, AIC = 333
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0659
# p-value = 0.882
# mStop = 20, deviance = 113, AIC = 296
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.707
# p-value = 0.0216
# mStop = 20, deviance = 413, AIC = 553
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.254
# p-value = 0.647
# mStop = 20, deviance = 348, AIC = 525
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.335
# p-value = 0.611
# mStop = 20, deviance = 319, AIC = 495
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.118
# p-value = 0.856
# mStop = 20, deviance = 103, AIC = 287
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.621
# p-value = 0.286
# mStop = 20, deviance = 626, AIC = 792
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.569
# p-value = 0.498
# mStop = 20, deviance = 406, AIC = 580
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.337
# p-value = 0.698
# mStop = 20, deviance = 281, AIC = 460
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.04
# p-value = 0.914
# mStop = 20, deviance = 73.1, AIC = 258
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.0443
# p-value = 0.936
# mStop = 20, deviance = 29.5, AIC = 215
#     fastPerm Two Sample Test
#
# difference of means
# 1,000 iterations within partitions
#
# observed statistic = 0.484
# p-value = 0.349
# mStop = 20, deviance = 566, AIC = 734
# 2771.9322946071625

# %%
2738 / 60
# Out:
# 45.63333333333333

# %%
# %R -o out

# %%
outT = out.T

# %%
P_fp_list =list(outT.values.ravel())

# %% [markdown]
# ### Parallelized exact test takes ~3s

# %%
from scipy import ks_2samp
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-152-5febb1c01185> in <module>
# ----> 1 from scipy import ks_2samp
#
# ImportError: cannot import name 'ks_2samp' from 'scipy' (/home/ekvall/anaconda3/envs/my-r-env/lib/python3.7/site-packages/scipy/__init__.py)

# %%
import scipy.stats

# %%
def MW(A, B):
    p_mw = list()
    for a,b in zip(A, B):
        p_mw.append(mannwhitneyu(a,b,alternative="two-sided")[1])
    return p_mw

# %%
start = time.time()

P_mw_list = MW(TNP_Arr, NotTNP_Arr)

end = time.time()
print(end - start)
# Out:
# 1.5224146842956543

# %% [markdown]
# ### Mann-Whitney exact test takes ~1s

# %%
start = time.time()

P_t_list = ttests(TNP_Arr, NotTNP_Arr, True)

end = time.time()
print(end - start)
# Out:
# 1.3865432739257812

# %%
P_t_list[:10]
# Out:
# [0.7838756116599749,
#  0.7917779329245839,
#  0.7997363924378036,
#  0.7856277364323173,
#  0.7899699442424601,
#  0.792930827009922,
#  0.7901890524008188,
#  0.789975666301694,
#  0.8427510224313053,
#  1.5240488954859144e-07]

# %%
P_mw_list[:10]
# Out:
# [0.609819653183949,
#  0.5944769748092975,
#  0.5944769748092975,
#  0.5894022362062368,
#  0.5944769748092975,
#  0.5944769748092975,
#  0.5944769748092975,
#  0.5944769748092975,
#  0.8572304287808331,
#  1.540399532870167e-06]

# %%
P2_e[:10]
# Out:
# [0.698104764207182,
#  0.6112025904761902,
#  0.6112025904761902,
#  0.6492721391995435,
#  0.6492721391995435,
#  0.6112025904761902,
#  0.6112025904761902,
#  0.6112025904761902,
#  1.2568111055420395,
#  6.573383859453941e-07]

# %%
P2_e =  [min(2*p, 2*(1-p)) for p in P_e_list]
#P2_e =  [2*p for p in P_e_list]

# %%
#df_e = pd.DataFrame({"p":P_e_list})
df_e = pd.DataFrame({"p":P2_e})
df_mw = pd.DataFrame({"p":P_mw_list})
df_tt = pd.DataFrame({"p":P_t_list})
df_fp = pd.DataFrame({"p":list(np.array(P_fp_list) )})

# %%
df_e = qvalues(df_e, pi0=None)
df_mw = qvalues(df_mw, pi0=None)
df_tt = qvalues(df_tt, pi0=None)
df_fp = qvalues(df_fp, pi0=None)

# %%
df_e["q"][df_e["q"]<0.01].shape
# Out:
# (774,)

# %%
df_mw["q"][df_mw["q"]<0.01].shape
# Out:
# (974,)

# %%
df_tt["q"][df_tt["q"]<0.01].shape
# Out:
# (832,)

# %%
df_fp["q"][df_fp["q"]<0.01].shape
# Out:
# (1005,)

# %%
data_e = df_e["q"][df_e["q"]<0.1]
data_mw = df_mw["q"][df_mw["q"]<0.1]
data_tt = df_tt["q"][df_tt["q"]<0.1]
data_fp = df_fp["q"][df_fp["q"]<0.1]

# %%
def preparePandas(q_values, cumulative, test="parallelized shift"):
    preparePd = list()
    for q, cum in zip(q_values, cumulative):
        preparePd.append([q, cum, test])
    return preparePd

# %%
values, base = np.histogram(data_e, bins=40)
cumulative = np.cumsum(values)
exactData = preparePandas(base[:-1], cumulative)

values, base = np.histogram(data_mw, bins=40)
cumulative = np.cumsum(values)
mwuData = preparePandas(base[:-1], cumulative, "MWU")

values, base = np.histogram(data_tt, bins=40)
cumulative = np.cumsum(values)
ttData = preparePandas(base[:-1], cumulative, "t test")

values, base = np.histogram(data_fp, bins=40)
cumulative = np.cumsum(values)
fpData = preparePandas(base[:-1], cumulative, "fastPerm")

# %%
D = exactData +  mwuData + ttData + fpData

# %%
D = exactData +  mwuData + ttData + fpData
pdData = pd.DataFrame(D, columns=['%','n', 'Method'])

# %%
a4_dims = (11.7, 8.27)

fig, ax = plt.subplots(figsize=a4_dims)

sns.set(style="white")
sns.set_context("talk")

snsPlot = sns.lineplot(x="%", y="n",
             hue="Method",
             data=pdData, ax=ax)

plt.ylabel(r"$n_{proteins}$",fontsize=20)
        
        
plt.xlabel(r"$q-value\ (\%)$",fontsize=15)

sns.set_style("ticks")
sns.despine()
plt.tight_layout()
plt.savefig("figures/experiment/n_proteins")

# %%
PE = np.array(P2_e)
PE[PE<0.1]
# Out:
# array([6.57338386e-07, 1.76960323e-04, 1.88472150e-02, ...,
#        2.70889140e-02, 1.29611500e-05, 4.75955216e-02])

# %%
PF = np.array(P_fp_list)
PT = np.array(P_t_list)

# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt

#data = pd.DataFrame(data={'x': PT[PT<0.1], 'y': PE[PT<0.1] })
#data = pd.DataFrame(data={'x': P_mw_list, 'y': P_t_list})

data = pd.DataFrame(data={'x': P_mw_list, 'y': P2_e})
#tips = sns.load_dataset("tips")
#f, ax = plt.subplots(figsize=(7, 7))

#ax.set(xscale="log", yscale="log")
#f, ax = plt.subplots(figsize=(7, 7))
#ax.set(xscale="log", yscale="log")
sns.scatterplot(x="x", y="y", data=data)#, size=0.1, ax=ax)

# %%
# !ls "figures/experiment/"

# %%
# %%R
# # dummy data
# set.seed(1)
# x <- runif(20)
# y <- 0.5 * x
# y <- y + rnorm(20)
#
# ## set up for the permutation, compute observed R
# nullR <- numeric(length = 1000)
# nullR[1] <- cor(x, y) ## obsered R in [1]
# N <- length(x)
#
#
# ## permutation test
# for(i in seq_len(999) + 1) {
#     nullR[i] <- cor(x[sample(N)], y)
# }
#
# hist(nullR)

# %%
x
