# %%
from utils2 import *
import time
from significance_of_mean_cuda import significance_of_mean_cuda

# %% [markdown]
# ### Get synthetic data

# %%
path = "figures/memoryAllocation"

# %%
num_examples  = 1_000

# %%
N = list(range(10,150,10))
s = [10,20,30]

# %%
allMemNList = list()
for bins in s:
    memList = list()
    for n in N:
        A = np.asarray([np.random.normal(0, 1, n) for _ in range(num_examples)])
        B = np.asarray([np.random.normal(1, 1, n) for _ in range(num_examples)])
        
        SGM = significance_of_mean_cuda(bins,dtype_v=np.uint16,dtype_A=np.float64)
        SGM.run(A,B)
        
        memList.append(SGM.mem_alloc)
        
    allMemNList.append(memList)
# Out:
# This data requires 13.948 MiB on the GPU.
# This data requires 51.156000000000006 MiB on the GPU.
# This data requires 107.25999999999999 MiB on the GPU.
# This data requires 185.156 MiB on the GPU.
# This data requires 278.46 MiB on the GPU.
# This data requires 383.812 MiB on the GPU.
# This data requires 531.932 MiB on the GPU.
# This data requires 683.3159999999999 MiB on the GPU.
# This data requires 862.3159999999999 MiB on the GPU.
# This data requires 1060.5 MiB on the GPU.
# This data requires 1250.748 MiB on the GPU.
# This data requires 1543.4759999999999 MiB on the GPU.
# This data requires 1790.5079999999998 MiB on the GPU.
# This data requires 1988.1 MiB on the GPU.
# This data requires 30.14 MiB on the GPU.
# This data requires 109.95599999999999 MiB on the GPU.
# This data requires 232.252 MiB on the GPU.
# This data requires 404.26 MiB on the GPU.
# This data requires 614.6519999999999 MiB on the GPU.
# This data requires 853.2679999999999 MiB on the GPU.
# This data requires 1177.1799999999998 MiB on the GPU.
# This data requires 1504.9799999999998 MiB on the GPU.
# This data requires 1913.548 MiB on the GPU.
# This data requires 2387.236 MiB on the GPU.
# This data requires 2792.316 MiB on the GPU.
# This data requires 3264.58 MiB on the GPU.
# This data requires 3932.62 MiB on the GPU.
# This data requires 4544.148 MiB on the GPU.
# This data requires 45.804 MiB on the GPU.
# This data requires 170.1 MiB on the GPU.
# This data requires 364.684 MiB on the GPU.
# This data requires 622.708 MiB on the GPU.
# This data requires 1000.62 MiB on the GPU.
# This data requires 1354.932 MiB on the GPU.
# This data requires 1779.26 MiB on the GPU.
# This data requires 2313.684 MiB on the GPU.
# This data requires 2982.252 MiB on the GPU.
# This data requires 3659.028 MiB on the GPU.
# This data requires 4269.948 MiB on the GPU.
# This data requires 5086.356000000001 MiB on the GPU.
# This data requires 6026.524 MiB on the GPU.
# This data requires 7043.796 MiB on the GPU.

# %%
plotSNS((allMemNList[0],r"$n_{w}=10$"), (allMemNList[1],r"$n_{w}=20$"), (allMemNList[2],
                                        r"$n_{w}=30$") , N, "Memory Alloc.(MiB)", r"$n$", log=False,path=getPATH(path, "N"))

# %%
N = [100, 120, 140]
s = list(range(10,30,2))

# %%
allMemSList = list()
for n in N:
    memList = list()
    for bins in s:
        A = np.asarray([np.random.normal(0, 1, n) for _ in range(num_examples)])
        B = np.asarray([np.random.normal(1, 1, n) for _ in range(num_examples)])
        
        SGM = significance_of_mean_cuda(bins,dtype_v=np.uint16,dtype_A=np.float64)
        SGM.run(A,B)
        
        memList.append(SGM.mem_alloc)
        
    allMemSList.append(memList)
# Out:
# This data requires 1055.652 MiB on the GPU.
# This data requires 1293.204 MiB on the GPU.
# This data requires 1619.636 MiB on the GPU.
# This data requires 1795.78 MiB on the GPU.
# This data requires 2096.356 MiB on the GPU.
# This data requires 2295.124 MiB on the GPU.
# This data requires 2573.076 MiB on the GPU.
# This data requires 2775.076 MiB on the GPU.
# This data requires 3104.74 MiB on the GPU.
# This data requires 3300.276 MiB on the GPU.
# This data requires 1477.6519999999998 MiB on the GPU.
# This data requires 1880.34 MiB on the GPU.
# This data requires 2226.884 MiB on the GPU.
# This data requires 2565.6839999999997 MiB on the GPU.
# This data requires 2908.3559999999998 MiB on the GPU.
# This data requires 3376.868 MiB on the GPU.
# This data requires 3810.5319999999997 MiB on the GPU.
# This data requires 4044.788 MiB on the GPU.
# This data requires 4385.524 MiB on the GPU.
# This data requires 4699.156 MiB on the GPU.
# This data requires 2021.9399999999998 MiB on the GPU.
# This data requires 2500.212 MiB on the GPU.
# This data requires 3059.7 MiB on the GPU.
# This data requires 3456.756 MiB on the GPU.
# This data requires 4009.4759999999997 MiB on the GPU.
# This data requires 4496.772 MiB on the GPU.
# This data requires 4869.012000000001 MiB on the GPU.
# This data requires 5627.028 MiB on the GPU.
# This data requires 6064.692 MiB on the GPU.
# This data requires 6326.388 MiB on the GPU.

# %%
plotSNS((allMemSList[0],r"$n=100$"), (allMemSList[1],r"$n=120$"), (allMemSList[2],
                                        r"$n=140$") , s, "Memory Alloc.(MiB)", r"$n_{w}$",path=getPATH(path, "bins"))
