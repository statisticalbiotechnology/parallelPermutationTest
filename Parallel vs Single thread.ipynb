# %%
from utils2 import *
import time
from significance_of_mean_cuda import significance_of_mean_cuda

# %% [markdown]
# ### Get synthetic data

# %%
num_examples = 1
N = [50,100, 150, 200, 250]
s =  [10, 50, 100, 200]
path = "figures/parallelVsSingleThread"

# %%
def runExperiment():
    cpu1 = list()
    gpu1 = list()
    n = N[1]
    for bins in s:
        np.random.seed(42)
        A = np.asarray([np.random.normal(0, 1, n) for _ in range(num_examples)])
        B = np.asarray([np.random.normal(1, 1, n) for _ in range(num_examples)])

        start = time.time()
        SGM = significance_of_mean_cuda(bins,dtype_v=np.uint16,dtype_A=np.float64)
        SGM.run(A,B)
        p = SGM.get_p_values()
        end = time.time()
        t_gpu = end - start
        gpu1.append(t_gpu)
        print("GPU: ", t_gpu)
    
    
        start = time.time()
        P = calibration_test(A,B,bins)
        end = time.time()
        t_cpu = end - start
        cpu1.append(t_cpu)
        print("CPU1: ",t_cpu)
    
        print(np.allclose(p,P))
    return cpu1, gpu1

# %%
if __name__=="__main__":
    cpu1, gpu1 = runExperiment()
    timePlotSNS(np.array(gpu1), np.array(cpu1), np.array(s), log=False, path=getPATH(path, "nonLog"))
    timePlotSNS(np.log10(np.array(gpu1)), np.log10(np.array(cpu1)), np.array(s), log=True, path=getPATH(path, "Log"))
# Out:
# This data requires 0.8294119999999999 MiB on the GPU.
# GPU:  0.035719871520996094
# CPU1:  0.14933228492736816
# True
# This data requires 4.8581 MiB on the GPU.
# GPU:  0.023515701293945312
# CPU1:  1.2780420780181885
# True
# This data requires 9.877396 MiB on the GPU.
# GPU:  0.03146958351135254
# CPU1:  2.548758029937744
# True
# This data requires 19.948308 MiB on the GPU.
# GPU:  0.09299850463867188
# CPU1:  5.355435848236084
# True
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-7-5dbaec483cad> in <module>
#       1 if __name__=="__main__":
#       2     cpu1, gpu1 = runExperiment()
# ----> 3     timePlotSNS(np.array(gpu1), np.array(cpu1), np.array(s), log=False, path=getPATH(path, "nonLog"))
#       4     timePlotSNS(np.log10(np.array(gpu1)), np.log10(np.array(cpu1)), np.array(s), log=True, path=getPATH(path, "Log"))
#
# ~/realFastPerm/parallelizedShiftExactPermTest/utils2.py in timePlotSNS(TIMEParallel, TIMEsingleThred, sampleShape, binVar, log, path)
#     134     if path:
#     135         fig = snsPlot.get_figure()
# --> 136         fig.savefig(path)
#     137
#     138 def getPATH(path, name):
#
# ~/.local/lib/python3.6/site-packages/matplotlib/figure.py in savefig(self, fname, frameon, transparent, **kwargs)
#    2092             self.set_frameon(frameon)
#    2093
# -> 2094         self.canvas.print_figure(fname, **kwargs)
#    2095
#    2096         if frameon:
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2073                     orientation=orientation,
#    2074                     bbox_inches_restore=_bbox_inches_restore,
# -> 2075                     **kwargs)
#    2076             finally:
#    2077                 if bbox_inches and restore_bbox:
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     519
#     520         with cbook._setattr_cm(renderer, dpi=self.figure.dpi), \
# --> 521                 cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     522             _png.write_png(renderer._renderer, fh,
#     523                             self.figure.dpi, metadata=metadata)
#
# ~/anaconda3/envs/kth-cluster/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~/.local/lib/python3.6/site-packages/matplotlib/cbook/__init__.py in open_file_cm(path_or_file, mode, encoding)
#     405 def open_file_cm(path_or_file, mode="r", encoding=None):
#     406     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 407     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     408     if opened:
#     409         with fh:
#
# ~/.local/lib/python3.6/site-packages/matplotlib/cbook/__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     390             fh = bz2.BZ2File(fname, flag)
#     391         else:
# --> 392             fh = open(fname, flag, encoding=encoding)
#     393         opened = True
#     394     elif hasattr(fname, 'seek'):
#
# PermissionError: [Errno 13] Permission denied: 'figures/parallelVsSingleThread/nonLog.png'
